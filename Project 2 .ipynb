# %% [markdown]
# # DataSet 1

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1= pd.read_excel('C:\\Users\\Prakhar\\Next Hikes\\Project 2\\project_2_dataset_1.xlsx')

# %% [markdown]
# # Head, Tail, Shape and Dimension of Dataset1

# %%
# Deatils of Dataset1

print('Columns of Dataset1')
print(df1.columns)

print('Head of Dataset1')
print(df1.head())

print('Tail of Dataset1')
print(df1.tail())

print('Shape of Dataset1')
print(df1.shape)

print('Dimension of Dataset1')
print(df1.ndim)
# Out:
# Columns of Dataset1
# Index(['instant', 'Date of Ride', 'season', 'yr', 'mnth', 'hr', 'holiday',
#        'weekday', 'weathersit', 'temp'],
#       dtype='object')
# Head of Dataset1
#    instant Date of Ride  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1   2011-01-01       1   0     1   0    False        6           1
# 1        2   2011-01-01       1   0     1   1    False        6           1
# 2        3   2011-01-01       1   0     1   2    False        6           1
# 3        4   2011-01-01       1   0     1   3    False        6           1
# 4        5   2011-01-01       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24
# Tail of Dataset1
#      instant Date of Ride  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606   2011-01-28       1   0     1  11    False        5           3
# 606      607   2011-01-28       1   0     1  12    False        5           3
# ...

# %% [markdown]
# # Describe, Correlation and Datatype of Dataset1

# %%
# Describe and Correlation of DF1

print('Describe of Dataset1')
print(df1.describe())

print('Correlation of Dataset1')
print(df1.corr())

print('Information of Dataset1')
print(df1.info())
# Out:
# Describe of Dataset1
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp
# count  610.000000
# mean     0.196885
# std      0.081304
# min      0.020000
# 25%      0.160000
# 50%      0.200000
# 75%      0.235000
# max      0.460000
# Correlation of Dataset1
# ...

# %%
df1.rename(columns={'dteday': 'Date of Ride'},inplace= True)

# %%
df1
# Out:
#      instant Date of Ride  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1   2011-01-01       1   0     1   0    False        6           1
# 1          2   2011-01-01       1   0     1   1    False        6           1
# 2          3   2011-01-01       1   0     1   2    False        6           1
# 3          4   2011-01-01       1   0     1   3    False        6           1
# 4          5   2011-01-01       1   0     1   4    False        6           1
# ..       ...          ...     ...  ..   ...  ..      ...      ...         ...
# 605      606   2011-01-28       1   0     1  11    False        5           3
# 606      607   2011-01-28       1   0     1  12    False        5           3
# 607      608   2011-01-28       1   0     1  13    False        5           3
# 608      609   2011-01-28       1   0     1  14    False        5           3
# 609      610   2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# ...

# %% [markdown]
# # Replace Season1= Spring, Season2= Summer, Season3= Fall, Season4= Winter

# %%
df1['season']=df1['season'].replace({1:'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'})

# %%
df1['season']
# Out:
# 0      Spring
# 1      Spring
# 2      Spring
# 3      Spring
# 4      Spring
#         ...
# 605    Spring
# 606    Spring
# 607    Spring
# 608    Spring
# 609    Spring
# Name: season, Length: 610, dtype: object

# %% [markdown]
# # Unique Value of Season

# %%
df1['season'].unique()
# Out:
# array(['Spring'], dtype=object)

# %% [markdown]
# # Whether Day is holiday or not

# %%
df1['holiday']= df1['holiday'].replace({False: 'Not a Holiday'})

# %%
df1
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  weekday  \
# 0          1   2011-01-01  Spring   0     1   0  Not a Holiday        6
# 1          2   2011-01-01  Spring   0     1   1  Not a Holiday        6
# 2          3   2011-01-01  Spring   0     1   2  Not a Holiday        6
# 3          4   2011-01-01  Spring   0     1   3  Not a Holiday        6
# 4          5   2011-01-01  Spring   0     1   4  Not a Holiday        6
# ..       ...          ...     ...  ..   ...  ..            ...      ...
# 605      606   2011-01-28  Spring   0     1  11  Not a Holiday        5
# 606      607   2011-01-28  Spring   0     1  12  Not a Holiday        5
# 607      608   2011-01-28  Spring   0     1  13  Not a Holiday        5
# 608      609   2011-01-28  Spring   0     1  14  Not a Holiday        5
# 609      610   2011-01-28  Spring   0     1  15  Not a Holiday        5
#
#      weathersit  temp
# 0             1  0.24
# 1             1  0.22
# 2             1  0.22
# ...

# %% [markdown]
# # Whether Day is a Working Day or Weekend

# %%
df1['weekday']= df1['weekday'].apply(lambda x: 'Working Days' if x>=6 else 'Weekend or Holiday')

# %%
df1
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0          1   2011-01-01  Spring   0     1   0  Not a Holiday
# 1          2   2011-01-01  Spring   0     1   1  Not a Holiday
# 2          3   2011-01-01  Spring   0     1   2  Not a Holiday
# 3          4   2011-01-01  Spring   0     1   3  Not a Holiday
# 4          5   2011-01-01  Spring   0     1   4  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 605      606   2011-01-28  Spring   0     1  11  Not a Holiday
# 606      607   2011-01-28  Spring   0     1  12  Not a Holiday
# 607      608   2011-01-28  Spring   0     1  13  Not a Holiday
# 608      609   2011-01-28  Spring   0     1  14  Not a Holiday
# 609      610   2011-01-28  Spring   0     1  15  Not a Holiday
#
#                 weekday  weathersit  temp
# 0          Working Days           1  0.24
# 1          Working Days           1  0.22
# 2          Working Days           1  0.22
# ...

# %% [markdown]
# # Unique value of Weekdays

# %%
df1['weekday'].unique()
# Out:
# array(['Working Days', 'Weekend or Holiday'], dtype=object)

# %% [markdown]
# # Weather 1: Clear, Few clouds, Partly cloudy, Partly cloudy

# %%
df1['weathersit']
# Out:
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# 1      Clear, Few clouds, Partly cloudy, Partly cloudy
# 2      Clear, Few clouds, Partly cloudy, Partly cloudy
# 3      Clear, Few clouds, Partly cloudy, Partly cloudy
# 4      Clear, Few clouds, Partly cloudy, Partly cloudy
#                             ...
# 605                                                  3
# 606                                                  3
# 607                                                  3
# 608                                                  3
# 609                                                  2
# Name: weathersit, Length: 610, dtype: object

# %%
df1['weathersit']= df1['weathersit'].replace({1: 'Clear, Few clouds, Partly cloudy, Partly cloudy'})

# %%
df1
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0          1   2011-01-01  Spring   0     1   0  Not a Holiday
# 1          2   2011-01-01  Spring   0     1   1  Not a Holiday
# 2          3   2011-01-01  Spring   0     1   2  Not a Holiday
# 3          4   2011-01-01  Spring   0     1   3  Not a Holiday
# 4          5   2011-01-01  Spring   0     1   4  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 605      606   2011-01-28  Spring   0     1  11  Not a Holiday
# 606      607   2011-01-28  Spring   0     1  12  Not a Holiday
# 607      608   2011-01-28  Spring   0     1  13  Not a Holiday
# 608      609   2011-01-28  Spring   0     1  14  Not a Holiday
# 609      610   2011-01-28  Spring   0     1  15  Not a Holiday
#
#                 weekday                                       weathersit  temp
# 0          Working Days  Clear, Few clouds, Partly cloudy, Partly cloudy  0.24
# ...

# %%
df1[(df1['weathersit']==2)]
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 5          6   2011-01-01  Spring   0     1   5  Not a Holiday
# 13        14   2011-01-01  Spring   0     1  13  Not a Holiday
# 14        15   2011-01-01  Spring   0     1  14  Not a Holiday
# 15        16   2011-01-01  Spring   0     1  15  Not a Holiday
# 16        17   2011-01-01  Spring   0     1  16  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 599      600   2011-01-28  Spring   0     1   5  Not a Holiday
# 600      601   2011-01-28  Spring   0     1   6  Not a Holiday
# 601      602   2011-01-28  Spring   0     1   7  Not a Holiday
# 602      603   2011-01-28  Spring   0     1   8  Not a Holiday
# 609      610   2011-01-28  Spring   0     1  15  Not a Holiday
#
#                 weekday weathersit  temp
# 5          Working Days          2  0.24
# 13         Working Days          2  0.46
# 14         Working Days          2  0.46
# 15         Working Days          2  0.44
# ...

# %% [markdown]
# # Weather 2= Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist

# %%
df1['weathersit']= df1['weathersit'].replace({2: 'Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist'})

# %%
df1[(df1['weathersit']==2)]
# Out:
# Empty DataFrame
# Columns: [instant, Date of Ride, season, yr, mnth, hr, holiday, weekday, weathersit, temp]
# Index: []

# %% [markdown]
# # Weather 3= Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain+Scattered clouds

# %%
df1[(df1['weathersit']==3)]
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 18        19   2011-01-01  Spring   0     1  18  Not a Holiday
# 19        20   2011-01-01  Spring   0     1  19  Not a Holiday
# 29        30   2011-01-02  Spring   0     1   6  Not a Holiday
# 31        32   2011-01-02  Spring   0     1   8  Not a Holiday
# 37        38   2011-01-02  Spring   0     1  14  Not a Holiday
# 38        39   2011-01-02  Spring   0     1  15  Not a Holiday
# 39        40   2011-01-02  Spring   0     1  16  Not a Holiday
# 142      143   2011-01-07  Spring   0     1   5  Not a Holiday
# 164      165   2011-01-08  Spring   0     1   3  Not a Holiday
# 165      166   2011-01-08  Spring   0     1   4  Not a Holiday
# 169      170   2011-01-08  Spring   0     1   8  Not a Holiday
# 170      171   2011-01-08  Spring   0     1   9  Not a Holiday
# 249      250   2011-01-11  Spring   0     1  18  Not a Holiday
# 250      251   2011-01-11  Spring   0     1  19  Not a Holiday
# ...

# %%
df1['weathersit']= df1['weathersit'].replace({3: 'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds'})

# %%
df1[(df1['weathersit']==3)]
# Out:
# Empty DataFrame
# Columns: [instant, Date of Ride, season, yr, mnth, hr, holiday, weekday, weathersit, temp]
# Index: []

# %%
df1
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0          1   2011-01-01  Spring   0     1   0  Not a Holiday
# 1          2   2011-01-01  Spring   0     1   1  Not a Holiday
# 2          3   2011-01-01  Spring   0     1   2  Not a Holiday
# 3          4   2011-01-01  Spring   0     1   3  Not a Holiday
# 4          5   2011-01-01  Spring   0     1   4  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 605      606   2011-01-28  Spring   0     1  11  Not a Holiday
# 606      607   2011-01-28  Spring   0     1  12  Not a Holiday
# 607      608   2011-01-28  Spring   0     1  13  Not a Holiday
# 608      609   2011-01-28  Spring   0     1  14  Not a Holiday
# 609      610   2011-01-28  Spring   0     1  15  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0          Working Days    Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Weather 4= Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog

# %%
df1[(df1['weathersit']==4)]
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 585      586   2011-01-26  Spring   0     1  16  Not a Holiday
#
#                 weekday weathersit  temp
# 585  Weekend or Holiday          4  0.22

# %%
df1['weathersit']= df1['weathersit'].replace({4: 'Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog'})

# %%
df1
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0          1   2011-01-01  Spring   0     1   0  Not a Holiday
# 1          2   2011-01-01  Spring   0     1   1  Not a Holiday
# 2          3   2011-01-01  Spring   0     1   2  Not a Holiday
# 3          4   2011-01-01  Spring   0     1   3  Not a Holiday
# 4          5   2011-01-01  Spring   0     1   4  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 605      606   2011-01-28  Spring   0     1  11  Not a Holiday
# 606      607   2011-01-28  Spring   0     1  12  Not a Holiday
# 607      608   2011-01-28  Spring   0     1  13  Not a Holiday
# 608      609   2011-01-28  Spring   0     1  14  Not a Holiday
# 609      610   2011-01-28  Spring   0     1  15  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0          Working Days    Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Unique value of Weather situation

# %%
df1['weathersit'].unique()
# Out:
# array(['Clear, Few clouds, Partly cloudy, Partly cloudy',
#        'Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist',
#        'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds',
#        'Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog'],
#       dtype=object)

# %% [markdown]
# # Temp - "feels like" temperature in Celsius

# %%
df1['temp']
# Out:
# 0      0.24
# 1      0.22
# 2      0.22
# 3      0.24
# 4      0.24
#        ...
# 605    0.18
# 606    0.18
# 607    0.18
# 608    0.22
# 609    0.20
# Name: temp, Length: 610, dtype: float64

# %%
df1['temp'].dtype
# Out:
# dtype('O')

# %%
df1['temp']= df1['temp'].apply(lambda x: 'feels like {int(x*100)} degreecelsius')

# %%
df1
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 0          1   2011-01-01  Spring  Not a Holiday        Working Days
# 1          2   2011-01-01  Spring  Not a Holiday        Working Days
# 2          3   2011-01-01  Spring  Not a Holiday        Working Days
# 3          4   2011-01-01  Spring  Not a Holiday        Working Days
# 4          5   2011-01-01  Spring  Not a Holiday        Working Days
# ..       ...          ...     ...            ...                 ...
# 605      606   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 606      607   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 607      608   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 608      609   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 609      610   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
#
#                                             weathersit  \
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Drop Unnecessary columns

# %%
df1.drop(['yr','mnth', 'hr'], axis=1, inplace = True)

# %%
df1
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 0          1   2011-01-01  Spring  Not a Holiday        Working Days
# 1          2   2011-01-01  Spring  Not a Holiday        Working Days
# 2          3   2011-01-01  Spring  Not a Holiday        Working Days
# 3          4   2011-01-01  Spring  Not a Holiday        Working Days
# 4          5   2011-01-01  Spring  Not a Holiday        Working Days
# ..       ...          ...     ...            ...                 ...
# 605      606   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 606      607   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 607      608   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 608      609   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 609      610   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
#
#                                             weathersit  \
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Missing Value of Dataset1

# %%
df1.isnull().sum()
# Out:
# instant         0
# Date of Ride    0
# season          0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# dtype: int64

# %% [markdown]
# # Dataset 2

# %%
df2= pd.read_excel('C:\\Users\\Prakhar\\Next Hikes\\Project 2\\project_2_dataset_2.xlsx')

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %% [markdown]
# # Head, Tail, Shape and Dimension of Dataset2

# %%
# Deatils of Dataset2

print('Columns of Dataset2')
print(df2.columns)

print('Head of Dataset2')
print(df2.head())

print('Tail of Dataset2')
print(df2.tail())

print('Shape of Dataset2')
print(df2.shape)

print('Dimension of Dataset2')
print(df2.ndim)
# Out:
# Columns of Dataset2
# Index(['Unnamed: 0', 'instant', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')
# Head of Dataset2
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1
# Tail of Dataset2
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# ...

# %% [markdown]
# # Describe, Correlation and Datatype of Dataset2

# %%
# Describe and Correlation of Dataset2

print('Describe of Dataset2')
print(df2.describe())

print('Correlation of Dataset2')
print(df2.corr())

print('Information of Dataset2')
print(df2.info())
# Out:
# Describe of Dataset2
#        Unnamed: 0     instant       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean   304.500000  305.500000    0.199935    0.562475    0.204851    4.501639
# std    176.236111  176.236111    0.078836    0.175440    0.121806    6.319945
# min      0.000000    1.000000    0.000000    0.210000    0.000000    0.000000
# 25%    152.250000  153.250000    0.151500    0.432500    0.104500    0.000000
# 50%    304.500000  305.500000    0.197000    0.520000    0.194000    2.000000
# 75%    456.750000  457.750000    0.242400    0.690000    0.283600    6.000000
# max    609.000000  610.000000    0.454500    1.000000    0.582100   47.000000
#
#        registered         cnt
# count  610.000000  610.000000
# mean    51.068852   55.570492
# std     47.021204   49.316802
# min      0.000000    1.000000
# 25%     14.000000   16.000000
# 50%     43.000000   47.000000
# ...

# %%
import math

# %% [markdown]
# # humidity - relative humidity

# %%
df2['hum']= df2['hum'].apply(lambda x: f'{int(x*100)} %')

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  81 %     0.0000       3          13   16
# 1             1        2  0.2727  80 %     0.0000       8          32   40
# 2             2        3  0.2727  80 %     0.0000       5          27   32
# 3             3        4  0.2879  75 %     0.0000       3          10   13
# 4             4        5  0.2879  75 %     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  93 %     0.1045       0          30   30
# 606         606      607  0.2121  93 %     0.1045       1          28   29
# 607         607      608  0.2121  93 %     0.1045       0          31   31
# 608         608      609  0.2727  80 %     0.0000       2          36   38
# 609         609      610  0.2576  86 %     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2.rename(columns= {'hum': 'Relative Humidity'}, inplace = True)

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp Relative Humidity  windspeed  casual  \
# 0             0        1  0.2879              81 %     0.0000       3
# 1             1        2  0.2727              80 %     0.0000       8
# 2             2        3  0.2727              80 %     0.0000       5
# 3             3        4  0.2879              75 %     0.0000       3
# 4             4        5  0.2879              75 %     0.0000       0
# ..          ...      ...     ...               ...        ...     ...
# 605         605      606  0.2121              93 %     0.1045       0
# 606         606      607  0.2121              93 %     0.1045       1
# 607         607      608  0.2121              93 %     0.1045       0
# 608         608      609  0.2727              80 %     0.0000       2
# 609         609      610  0.2576              86 %     0.0000       1
#
#      registered  cnt
# 0            13   16
# 1            32   40
# 2            27   32
# 3            10   13
# ...

# %% [markdown]
# # windspeed - wind speed

# %%
df2['windspeed'].unique()
# Out:
# array([0.    , 0.0896, 0.2537, 0.2836, 0.2985, 0.194 , 0.2239, 0.1343,
#        0.1642, 0.3284, 0.4478, 0.3582, 0.4179, 0.3881, 0.1045, 0.4925,
#        0.5522, 0.4627, 0.5224, 0.5821])

# %% [markdown]
# # Central tendancy of Windspeed

# %%
#Central Tendancy of Windspeed

print('Mean of Windspeed')
print(df2['windspeed'].mean())

print('Median of Windspeed')
print(df2['windspeed'].median())

print('Mode of Windspeed')
print(df2['windspeed'].mode())
# Out:
# Mean of Windspeed
# 0.20485098360655737
# Median of Windspeed
# 0.194
# Mode of Windspeed
# 0    0.1642
# Name: windspeed, dtype: float64

# %% [markdown]
# #  casual - number of non-registered user rentals initiated

# %%
df2['casual'].unique()
# Out:
# array([ 3,  8,  5,  0,  2,  1, 12, 26, 29, 47, 35, 40, 41, 15,  9,  6, 11,
#         4,  7, 16, 20, 19, 10, 13, 14, 18, 17, 21, 33, 23, 22, 24],
#       dtype=int64)

# %% [markdown]
# # Central Tendency of non Registered User rentals

# %%
#Central Tendancy

print('Mean of Casual')
print(df2['casual'].mean())

print('Median of Casual')
print(df2['casual'].median())

print('Mode of Casual')
print(df2['casual'].mode())
# Out:
# Mean of Casual
# 4.501639344262295
# Median of Casual
# 2.0
# Mode of Casual
# 0    0
# Name: casual, dtype: int64

# %% [markdown]
# # Registered - number of registered user rentals initiated

# %%
df2['registered'].unique()
# Out:
# array([ 13,  32,  27,  10,   1,   0,   2,   7,   6,  24,  30,  55,  47,
#         71,  70,  52,  26,  31,  25,  17,  16,   8,   4,  19,  46,  54,
#         73,  64,  67,  58,  43,  29,  20,   9,   5,   3,  63, 153,  81,
#         33,  41,  48,  53,  66, 146, 148, 102,  49,  11,  36,  92, 177,
#         98,  37,  50,  79,  68, 202, 179, 110,  34,  87, 192, 109,  74,
#         65,  85, 186, 166, 127,  82,  40,  18,  95, 216, 116,  42,  57,
#         78,  59, 163, 158,  51,  76, 190, 125, 178,  39,  14,  15,  56,
#         60,  90,  83,  69,  28,  35,  22,  12,  77,  44,  38,  75, 184,
#        174, 154,  97, 214,  45,  72, 130,  94, 139, 135, 197, 137, 141,
#        156, 117, 155, 134,  89,  80, 108,  61, 124, 132, 196, 107, 100,
#        247, 140,  86,  62, 207, 210, 159, 151, 119,  93,  23, 171, 145,
#        101,  21, 103, 233, 208, 218, 133], dtype=int64)

# %% [markdown]
# # Central Tendency of Registered User rentals

# %%
#Central Tendancy of Registered

print('Mean of Registered')
print(df2['registered'].mean())

print('Median of Registered')
print(df2['registered'].median())

print('Mode of Registered')
print(df2['registered'].mode())
# Out:
# Mean of Registered
# 51.06885245901639
# Median of Registered
# 43.0
# Mode of Registered
# 0    1
# Name: registered, dtype: int64

# %% [markdown]
# # count - number of total rentals

# %%
df2['cnt'].unique()
# Out:
# array([ 16,  40,  32,  13,   1,   2,   3,   8,  14,  36,  56,  84,  94,
#        106, 110,  93,  67,  35,  37,  34,  28,  39,  17,   9,   6,  20,
#         53,  70,  75,  59,  74,  76,  65,  30,  22,  31,   5,  64, 154,
#         88,  44,  51,  61,  77,  72, 157,  52,  12,   4, 179, 100,  42,
#         57,  78,  97,  63,  83, 212, 182, 112,  54,  48,  11,  33, 195,
#        115,  46,  79,  71,  62,  89, 190, 169, 132,  43,  19,  95, 219,
#        122,  45,  86, 172, 163,  69,  23,   7, 210, 134,  73,  50,  87,
#        187, 123,  15,  25,  98, 102,  55,  10,  49,  82,  92,  41,  38,
#        188,  47, 178, 155,  24,  18,  27,  99, 217, 130, 136,  29, 128,
#         81,  68, 139, 137, 202,  60, 162, 144, 158, 117,  90, 159, 101,
#        118, 129,  26, 104,  91, 113, 105,  21,  80, 125, 133, 197, 109,
#        161, 249, 143, 215, 185, 152, 126, 166, 120,  96, 103,  58, 116,
#        177, 184, 153, 108, 238, 222, 225, 146, 119], dtype=int64)

# %% [markdown]
# # Central Tendency of Total rentals

# %%
#Central Tendancy of Total Rentals

print('Mean of Total Rentals')
print(df2['cnt'].mean())

print('Median of Total Rentals')
print(df2['cnt'].median())

print('Mode of Total Rentals')
print(df2['cnt'].mode())
# Out:
# Mean of Total Rentals
# 55.570491803278685
# Median of Total Rentals
# 47.0
# Mode of Total Rentals
# 0    1
# Name: cnt, dtype: int64

# %%
df2.rename(columns= {'cnt': 'Total Rentals'}, inplace= True)

# %% [markdown]
# # Missing value of Dataset2

# %%
df2.isnull().sum()
# Out:
# instant              0
# atemp                0
# Relative Humidity    0
# windspeed            0
# casual               0
# registered           0
# Total Rentals        0
# dtype: int64

# %%
df2['atemp'].mean()
# Out:
# 0.19993489148580967

# %%
df2['atemp'].fillna(df2['atemp'].mean(), inplace=True)

# %%
df2.isnull().sum()
# Out:
# instant              0
# atemp                0
# Relative Humidity    0
# windspeed            0
# casual               0
# registered           0
# Total Rentals        0
# dtype: int64

# %% [markdown]
# # Dropping Unnecessary Column

# %%
df2.drop('Unnamed: 0', axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[256], line 1
# ----> 1 df2.drop('Unnamed: 0', axis=1, inplace= True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df2
# Out:
#      instant   atemp Relative Humidity  windspeed  casual  registered  \
# 0          1  0.2879              81 %     0.0000       3          13
# 1          2  0.2727              80 %     0.0000       8          32
# 2          3  0.2727              80 %     0.0000       5          27
# 3          4  0.2879              75 %     0.0000       3          10
# 4          5  0.2879              75 %     0.0000       0           1
# ..       ...     ...               ...        ...     ...         ...
# 605      606  0.2121              93 %     0.1045       0          30
# 606      607  0.2121              93 %     0.1045       1          28
# 607      608  0.2121              93 %     0.1045       0          31
# 608      609  0.2727              80 %     0.0000       2          36
# 609      610  0.2576              86 %     0.0000       1          40
#
#      Total Rentals
# 0               16
# 1               40
# 2               32
# 3               13
# 4                1
# ...

# %% [markdown]
# # Merging- Dataset 1 & Dataset 2

# %%
dfmerge= pd.merge(df1, df2, on= 'instant', how= 'inner')

# %%
dfmerge
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 0          1   2011-01-01  Spring  Not a Holiday        Working Days
# 1          2   2011-01-01  Spring  Not a Holiday        Working Days
# 2          3   2011-01-01  Spring  Not a Holiday        Working Days
# 3          4   2011-01-01  Spring  Not a Holiday        Working Days
# 4          5   2011-01-01  Spring  Not a Holiday        Working Days
# ..       ...          ...     ...            ...                 ...
# 605      606   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 606      607   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 607      608   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 608      609   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 609      610   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
#
#                                             weathersit  \
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %%
dfmerge.to_excel('Merged_Dataset.xlsx')

# %% [markdown]
# # Dataset 3

# %%
df3= pd.read_excel('C:\\Users\\Prakhar\\Next Hikes\\Project 2\\project_2_dataset_3.xlsx')

# %%
df3
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %% [markdown]
# # Head, Tail, Shape and Dimension of Dataset3

# %%
# Deatils of Dataset3

print('Columns of Dataset3')
print(df3.columns)

print('Head of Dataset3')
print(df3.head())

print('Tail of Dataset3')
print(df3.tail())

print('Shape of Dataset3')
print(df3.shape)

print('Dimension of Dataset3')
print(df3.ndim)
# Out:
# Columns of Dataset3
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')
# Head of Dataset3
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620 2011-01-29       1   0     1   1    False        6           1
# 1      621 2011-01-29       1   0     1   2    False        6           1
# 2      622 2011-01-29       1   0     1   3    False        6           1
# 3      623 2011-01-29       1   0     1   4    False        6           1
# 4      624 2011-01-29       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# ...

# %% [markdown]
# # Describe, Correlation and Datatype of Dataset3

# %%
# Describe and Correlation of Dataset3

print('Describe of Dataset3')
print(df3.describe())

print('Correlation of Dataset3')
print(df3.corr())

print('Information of Dataset3')
print(df3.info())
# Out:
# Describe of Dataset3
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum   windspeed      casual  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     1.484615    0.220000    0.230424    0.613769    0.179416    5.576923
# std      0.663805    0.073095    0.069455    0.202361    0.138551    9.317478
# ...

# %%
df3.rename(columns={'dteday': 'Date of Ride'},inplace= True)

# %%
df3
# Out:
#      instant Date of Ride  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620   2011-01-29       1   0     1   1    False        6           1
# 1        621   2011-01-29       1   0     1   2    False        6           1
# 2        622   2011-01-29       1   0     1   3    False        6           1
# 3        623   2011-01-29       1   0     1   4    False        6           1
# 4        624   2011-01-29       1   0     1   6    False        6           1
# ..       ...          ...     ...  ..   ...  ..      ...      ...         ...
# 385      615   2011-01-28       1   0     1  20    False        5           2
# 386      616   2011-01-28       1   0     1  21    False        5           2
# 387      617   2011-01-28       1   0     1  22    False        5           1
# 388      618   2011-01-28       1   0     1  23    False        5           1
# 389      619   2011-01-29       1   0     1   0    False        6           1
#
# ...

# %% [markdown]
# # Replace Season1= Spring, Season2= Summer, Season3= Fall, Season4= Winter in Dataset3

# %%
df3['season']=df3['season'].replace({1:'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'})

# %%
df3
# Out:
#      instant Date of Ride  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620   2011-01-29  Spring   0     1   1    False        6           1
# 1        621   2011-01-29  Spring   0     1   2    False        6           1
# 2        622   2011-01-29  Spring   0     1   3    False        6           1
# 3        623   2011-01-29  Spring   0     1   4    False        6           1
# 4        624   2011-01-29  Spring   0     1   6    False        6           1
# ..       ...          ...     ...  ..   ...  ..      ...      ...         ...
# 385      615   2011-01-28  Spring   0     1  20    False        5           2
# 386      616   2011-01-28  Spring   0     1  21    False        5           2
# 387      617   2011-01-28  Spring   0     1  22    False        5           1
# 388      618   2011-01-28  Spring   0     1  23    False        5           1
# 389      619   2011-01-29  Spring   0     1   0    False        6           1
#
# ...

# %%
df3[(df3['season']==2)]
# Out:
# Empty DataFrame
# Columns: [instant, Date of Ride, season, yr, mnth, hr, holiday, weekday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
df3[(df3['season']==3)]
# Out:
# Empty DataFrame
# Columns: [instant, Date of Ride, season, yr, mnth, hr, holiday, weekday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
df3[(df3['season']==4)]
# Out:
# Empty DataFrame
# Columns: [instant, Date of Ride, season, yr, mnth, hr, holiday, weekday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %% [markdown]
# # Whether Day is holiday or not

# %%
df3['holiday']= df3['holiday'].replace({False: 'Not a Holiday'})

# %%
df3
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  weekday  \
# 0        620   2011-01-29  Spring   0     1   1  Not a Holiday        6
# 1        621   2011-01-29  Spring   0     1   2  Not a Holiday        6
# 2        622   2011-01-29  Spring   0     1   3  Not a Holiday        6
# 3        623   2011-01-29  Spring   0     1   4  Not a Holiday        6
# 4        624   2011-01-29  Spring   0     1   6  Not a Holiday        6
# ..       ...          ...     ...  ..   ...  ..            ...      ...
# 385      615   2011-01-28  Spring   0     1  20  Not a Holiday        5
# 386      616   2011-01-28  Spring   0     1  21  Not a Holiday        5
# 387      617   2011-01-28  Spring   0     1  22  Not a Holiday        5
# 388      618   2011-01-28  Spring   0     1  23  Not a Holiday        5
# 389      619   2011-01-29  Spring   0     1   0  Not a Holiday        6
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# # Unique Value of Holiday

# %%
df3['holiday'].unique()
# Out:
# array(['Not a Holiday'], dtype=object)

# %% [markdown]
# # Whether Day is a Working Day or Weekend

# %%
df3['weekday']= df3['weekday'].apply(lambda x: 'Working Days' if x>=6 else 'Weekend or Holiday')

# %%
df3
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0        620   2011-01-29  Spring   0     1   1  Not a Holiday
# 1        621   2011-01-29  Spring   0     1   2  Not a Holiday
# 2        622   2011-01-29  Spring   0     1   3  Not a Holiday
# 3        623   2011-01-29  Spring   0     1   4  Not a Holiday
# 4        624   2011-01-29  Spring   0     1   6  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 385      615   2011-01-28  Spring   0     1  20  Not a Holiday
# 386      616   2011-01-28  Spring   0     1  21  Not a Holiday
# 387      617   2011-01-28  Spring   0     1  22  Not a Holiday
# 388      618   2011-01-28  Spring   0     1  23  Not a Holiday
# 389      619   2011-01-29  Spring   0     1   0  Not a Holiday
#
#                 weekday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0          Working Days           1  0.22  0.2273  0.64     0.1940       0
# ...

# %%
df3['weekday'].unique()
# Out:
# array(['Working Days', 'Weekend or Holiday'], dtype=object)

# %% [markdown]
# # Weather 1: Clear, Few clouds, Partly cloudy, Partly cloudy

# %%
df3['weathersit']= df3['weathersit'].replace({1: 'Clear, Few clouds, Partly cloudy, Partly cloudy'})

# %%
df3
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0        620   2011-01-29  Spring   0     1   1  Not a Holiday
# 1        621   2011-01-29  Spring   0     1   2  Not a Holiday
# 2        622   2011-01-29  Spring   0     1   3  Not a Holiday
# 3        623   2011-01-29  Spring   0     1   4  Not a Holiday
# 4        624   2011-01-29  Spring   0     1   6  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 385      615   2011-01-28  Spring   0     1  20  Not a Holiday
# 386      616   2011-01-28  Spring   0     1  21  Not a Holiday
# 387      617   2011-01-28  Spring   0     1  22  Not a Holiday
# 388      618   2011-01-28  Spring   0     1  23  Not a Holiday
# 389      619   2011-01-29  Spring   0     1   0  Not a Holiday
#
#                 weekday                                       weathersit  \
# 0          Working Days  Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Weather 2= Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist

# %%
df3['weathersit']= df3['weathersit'].replace({2: 'Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist'})

# %%
df3
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0        620   2011-01-29  Spring   0     1   1  Not a Holiday
# 1        621   2011-01-29  Spring   0     1   2  Not a Holiday
# 2        622   2011-01-29  Spring   0     1   3  Not a Holiday
# 3        623   2011-01-29  Spring   0     1   4  Not a Holiday
# 4        624   2011-01-29  Spring   0     1   6  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 385      615   2011-01-28  Spring   0     1  20  Not a Holiday
# 386      616   2011-01-28  Spring   0     1  21  Not a Holiday
# 387      617   2011-01-28  Spring   0     1  22  Not a Holiday
# 388      618   2011-01-28  Spring   0     1  23  Not a Holiday
# 389      619   2011-01-29  Spring   0     1   0  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0          Working Days    Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Weather 3= Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain+Scattered clouds

# %%
df3['weathersit']= df3['weathersit'].replace({3: 'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds'})

# %%
df3
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0        620   2011-01-29  Spring   0     1   1  Not a Holiday
# 1        621   2011-01-29  Spring   0     1   2  Not a Holiday
# 2        622   2011-01-29  Spring   0     1   3  Not a Holiday
# 3        623   2011-01-29  Spring   0     1   4  Not a Holiday
# 4        624   2011-01-29  Spring   0     1   6  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 385      615   2011-01-28  Spring   0     1  20  Not a Holiday
# 386      616   2011-01-28  Spring   0     1  21  Not a Holiday
# 387      617   2011-01-28  Spring   0     1  22  Not a Holiday
# 388      618   2011-01-28  Spring   0     1  23  Not a Holiday
# 389      619   2011-01-29  Spring   0     1   0  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0          Working Days    Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Weather 4= Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog

# %%
df3['weathersit']= df3['weathersit'].replace({4: 'Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog'})

# %%
df3
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0        620   2011-01-29  Spring   0     1   1  Not a Holiday
# 1        621   2011-01-29  Spring   0     1   2  Not a Holiday
# 2        622   2011-01-29  Spring   0     1   3  Not a Holiday
# 3        623   2011-01-29  Spring   0     1   4  Not a Holiday
# 4        624   2011-01-29  Spring   0     1   6  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 385      615   2011-01-28  Spring   0     1  20  Not a Holiday
# 386      616   2011-01-28  Spring   0     1  21  Not a Holiday
# 387      617   2011-01-28  Spring   0     1  22  Not a Holiday
# 388      618   2011-01-28  Spring   0     1  23  Not a Holiday
# 389      619   2011-01-29  Spring   0     1   0  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0          Working Days    Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Unique value of Weather situation

# %%
df3['weathersit'].unique()
# Out:
# array(['Clear, Few clouds, Partly cloudy, Partly cloudy',
#        'Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist',
#        'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds'],
#       dtype=object)

# %% [markdown]
# # Temp - "feels like" temperature in Celsius

# %%
df3['temp']
# Out:
# 0      0.22
# 1      0.22
# 2      0.20
# 3      0.16
# 4      0.16
#        ...
# 385    0.24
# 386    0.22
# 387    0.24
# 388    0.24
# 389    0.22
# Name: temp, Length: 390, dtype: float64

# %%
df3['temp']= df3['temp'].apply(lambda x: 'feels like {int(x*100)} degree celsius')

# %%
df3
# Out:
#      instant Date of Ride  season  yr  mnth  hr        holiday  \
# 0        620   2011-01-29  Spring   0     1   1  Not a Holiday
# 1        621   2011-01-29  Spring   0     1   2  Not a Holiday
# 2        622   2011-01-29  Spring   0     1   3  Not a Holiday
# 3        623   2011-01-29  Spring   0     1   4  Not a Holiday
# 4        624   2011-01-29  Spring   0     1   6  Not a Holiday
# ..       ...          ...     ...  ..   ...  ..            ...
# 385      615   2011-01-28  Spring   0     1  20  Not a Holiday
# 386      616   2011-01-28  Spring   0     1  21  Not a Holiday
# 387      617   2011-01-28  Spring   0     1  22  Not a Holiday
# 388      618   2011-01-28  Spring   0     1  23  Not a Holiday
# 389      619   2011-01-29  Spring   0     1   0  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0          Working Days    Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Drop Columns

# %%
df3.drop(['yr','mnth','hr'], axis=1, inplace= True)

# %%
df3
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 0        620   2011-01-29  Spring  Not a Holiday        Working Days
# 1        621   2011-01-29  Spring  Not a Holiday        Working Days
# 2        622   2011-01-29  Spring  Not a Holiday        Working Days
# 3        623   2011-01-29  Spring  Not a Holiday        Working Days
# 4        624   2011-01-29  Spring  Not a Holiday        Working Days
# ..       ...          ...     ...            ...                 ...
# 385      615   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 386      616   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 387      617   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 388      618   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 389      619   2011-01-29  Spring  Not a Holiday        Working Days
#
#                                             weathersit  \
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Humidity= Relative Humidity

# %%
df3['hum']= df3['hum'].apply(lambda x: f'{int(x*100)} %')

# %%
df3
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 0        620   2011-01-29  Spring  Not a Holiday        Working Days
# 1        621   2011-01-29  Spring  Not a Holiday        Working Days
# 2        622   2011-01-29  Spring  Not a Holiday        Working Days
# 3        623   2011-01-29  Spring  Not a Holiday        Working Days
# 4        624   2011-01-29  Spring  Not a Holiday        Working Days
# ..       ...          ...     ...            ...                 ...
# 385      615   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 386      616   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 387      617   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 388      618   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 389      619   2011-01-29  Spring  Not a Holiday        Working Days
#
#                                             weathersit  \
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %%
df3.rename(columns= {'hum': 'Relative Humidity'}, inplace = True)

# %%
df3
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 0        620   2011-01-29  Spring  Not a Holiday        Working Days
# 1        621   2011-01-29  Spring  Not a Holiday        Working Days
# 2        622   2011-01-29  Spring  Not a Holiday        Working Days
# 3        623   2011-01-29  Spring  Not a Holiday        Working Days
# 4        624   2011-01-29  Spring  Not a Holiday        Working Days
# ..       ...          ...     ...            ...                 ...
# 385      615   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 386      616   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 387      617   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 388      618   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 389      619   2011-01-29  Spring  Not a Holiday        Working Days
#
#                                             weathersit  \
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %%
df3['windspeed'].unique()
# Out:
# array([0.194 , 0.1642, 0.1343, 0.1045, 0.0896, 0.2537, 0.    , 0.2836,
#        0.2239, 0.3284, 0.2985, 0.3881, 0.5224, 0.5522, 0.4925, 0.4478,
#        0.3582, 0.4179, 0.4627, 0.5821])

# %% [markdown]
# # Central Tendancy of Windspeed

# %%
#Central Tendancy of Windspeed

print('Mean of Windspeed')
print(df3['windspeed'].mean())

print('Median of Windspeed')
print(df3['windspeed'].median())

print('Mode of Windspeed')
print(df3['windspeed'].mode())
# Out:
# Mean of Windspeed
# 0.17941589743589745
# Median of Windspeed
# 0.1642
# Mode of Windspeed
# 0    0.0
# Name: windspeed, dtype: float64

# %% [markdown]
# # casual - number of non-registered user rentals initiated

# %%
df3['casual'].unique()
# Out:
# array([ 0,  3,  1,  4, 12,  9, 10, 22, 19,  6,  7, 13, 18, 14,  8,  2,  5,
#        15, 11, 28, 48, 47, 52, 42, 24, 16, 21, 17, 30, 27, 32, 26, 58, 62,
#        51, 40], dtype=int64)

# %% [markdown]
# # Central Tendancy of Non Registered User Rentals

# %%
#Central Tendancy of Non Registered User Rentals

print('Mean of Casual')
print(df3['casual'].mean())

print('Median of Casual')
print(df3['casual'].median())

print('Mode of Casual')
print(df3['casual'].mode())
# Out:
# Mean of Casual
# 5.576923076923077
# Median of Casual
# 3.0
# Mode of Casual
# 0    0
# Name: casual, dtype: int64

# %% [markdown]
# # Central Tendancy of Registered User Rentals

# %%
df3['registered'].unique()
# Out:
# array([ 20,  15,   5,   2,   4,  31,  34,  51,  60,  66,  56,  89,  98,
#         88,  82,  59,  52,  42,  35,  28,  30,  33,  22,  10,   7,   1,
#          3,  11,  57,  50,  87,  71, 104,  95,  46,  25,  19,  16,   6,
#          8,  37, 182, 112,  68,  62,  85,  41,  83, 155, 153, 108,  78,
#         53, 132, 114,  47,  49,  45,  61, 172, 165, 105,  69,  64,   0,
#         17,  48, 154, 119,  74, 183, 175,  29,  39,  86, 184, 127,  55,
#         67,  43,  73, 170, 145,  92,  26, 217, 124,  76,  81,  91, 195,
#        152, 102,  36,  12,   9,  63,  40,  21,  38, 126, 135, 130, 115,
#         97,  65,  14, 223,  54, 207, 123,  75, 236, 128,  44,  79, 151,
#        100, 198,  72, 157, 168,  84,  99, 173, 121, 159, 110,  93,  70,
#         23, 212, 111, 193,  94,  27,  13, 103,  90, 113, 122, 106,  32,
#         96, 147, 107], dtype=int64)

# %%
#Central Tendancy of Registered

print('Mean of Registered')
print(df3['registered'].mean())

print('Median of Registered')
print(df3['registered'].median())

print('Mode of Registered')
print(df3['registered'].mode())
# Out:
# Mean of Registered
# 57.0025641025641
# Median of Registered
# 48.0
# Mode of Registered
# 0    1
# Name: registered, dtype: int64

# %%
df3['cnt'].unique()
# Out:
# array([ 20,  15,   8,   3,   2,   5,  34,  55,  64,  78,  65,  99, 120,
#        107,  91,  68,  58,  43,  36,  32,  33,  29,  11,   1,  12,  38,
#         59,  97,  84, 122, 109, 123,  77,  28,  21,   7,  37,  72, 185,
#        112,  69,  48,  54,  86,  44, 161, 156, 111,  56,  17,  22,  52,
#        135, 116,  47,  51, 176, 168, 108,  74,  16,   4,  18,  49, 155,
#         61,  75,  63,  76, 103, 190, 182,  40,  39,  87, 188, 133,  60,
#        175, 147,  96,  41,  13, 220, 127,  82,  90, 205,  71,  46,  31,
#          9,  10,  83,  45,  23,  89, 117, 174, 157, 121,  26,  27,  62,
#         30,  95, 230, 118,  66,  50, 114, 216, 128,  88,  25, 100, 243,
#        152, 101, 199,  79, 166, 170,   6, 178,  35,  80, 165, 160,  14,
#         24, 140, 110, 125, 211,  53, 145, 137, 105, 154, 162, 134,  98,
#        149], dtype=int64)

# %% [markdown]
# # Central Tendancy of Total Rentals

# %%
#Central Tendancy of Total Rentals

print('Mean of Total Rentals')
print(df3['cnt'].mean())

print('Median of Total Rentals')
print(df3['cnt'].median())

print('Mode of Total Rentals')
print(df3['cnt'].mode())
# Out:
# Mean of Total Rentals
# 62.57948717948718
# Median of Total Rentals
# 52.0
# Mode of Total Rentals
# 0    2
# Name: cnt, dtype: int64

# %%
df3.rename(columns= {'cnt': 'Total Rentals'}, inplace= True)

# %% [markdown]
# # Missing Value

# %%
df3.isnull().sum()
# Out:
# instant              0
# Date of Ride         0
# season               0
# holiday              0
# weekday              0
# weathersit           0
# temp                 0
# atemp                0
# Relative Humidity    0
# windspeed            0
# casual               0
# registered           0
# Total Rentals        0
# dtype: int64

# %% [markdown]
# # Concatenate Datasets

# %%
Final_dataset= pd.concat([dfmerge,df3])

# %%
Final_dataset
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 0          1   2011-01-01  Spring  Not a Holiday        Working Days
# 1          2   2011-01-01  Spring  Not a Holiday        Working Days
# 2          3   2011-01-01  Spring  Not a Holiday        Working Days
# 3          4   2011-01-01  Spring  Not a Holiday        Working Days
# 4          5   2011-01-01  Spring  Not a Holiday        Working Days
# ..       ...          ...     ...            ...                 ...
# 385      615   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 386      616   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 387      617   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 388      618   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 389      619   2011-01-29  Spring  Not a Holiday        Working Days
#
#                                             weathersit  \
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %%
Final_dataset.isnull().sum()
# Out:
# instant              0
# Date of Ride         0
# season               0
# holiday              0
# weekday              0
# weathersit           0
# temp                 0
# atemp                0
# Relative Humidity    0
# windspeed            0
# casual               0
# registered           0
# cnt                  0
# dtype: int64

# %% [markdown]
# # Outliers

# %%
Final_dataset
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 0          1   2011-01-01  Spring  Not a Holiday        Working Days
# 1          2   2011-01-01  Spring  Not a Holiday        Working Days
# 2          3   2011-01-01  Spring  Not a Holiday        Working Days
# 3          4   2011-01-01  Spring  Not a Holiday        Working Days
# 4          5   2011-01-01  Spring  Not a Holiday        Working Days
# ..       ...          ...     ...            ...                 ...
# 385      615   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 386      616   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 387      617   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 388      618   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 389      619   2011-01-29  Spring  Not a Holiday        Working Days
#
#                                             weathersit  \
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %%
Q1= Final_dataset['cnt'].quantile(0.25)
Q3= Final_dataset['cnt'].quantile(0.75)
IQR= Q3-Q1
threshold= 1.5

# %%
outliers= Final_dataset[(Final_dataset['cnt'] < Q1- threshold*IQR) | (Final_dataset['cnt'] > Q3 + threshold*IQR)]

# %%
outliers
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 76        77   2011-01-04  Spring  Not a Holiday  Weekend or Holiday
# 85        86   2011-01-04  Spring  Not a Holiday  Weekend or Holiday
# 86        87   2011-01-04  Spring  Not a Holiday  Weekend or Holiday
# 99       100   2011-01-05  Spring  Not a Holiday  Weekend or Holiday
# 108      109   2011-01-05  Spring  Not a Holiday  Weekend or Holiday
# 122      123   2011-01-06  Spring  Not a Holiday  Weekend or Holiday
# 145      146   2011-01-07  Spring  Not a Holiday  Weekend or Holiday
# 154      155   2011-01-07  Spring  Not a Holiday  Weekend or Holiday
# 217      218   2011-01-10  Spring  Not a Holiday  Weekend or Holiday
# 226      227   2011-01-10  Spring  Not a Holiday  Weekend or Holiday
# 239      240   2011-01-11  Spring  Not a Holiday  Weekend or Holiday
# 285      286   2011-01-13  Spring  Not a Holiday  Weekend or Holiday
# 415      416   2011-01-19  Spring  Not a Holiday  Weekend or Holiday
# ...

# %% [markdown]
# # Removing Outliers

# %%
Final_dataset_No_Outliers= Final_dataset.drop(outliers.index)

# %%
Final_dataset_No_Outliers
# Out:
#      instant Date of Ride  season        holiday             weekday  \
# 0          1   2011-01-01  Spring  Not a Holiday        Working Days
# 1          2   2011-01-01  Spring  Not a Holiday        Working Days
# 2          3   2011-01-01  Spring  Not a Holiday        Working Days
# 3          4   2011-01-01  Spring  Not a Holiday        Working Days
# 4          5   2011-01-01  Spring  Not a Holiday        Working Days
# ..       ...          ...     ...            ...                 ...
# 385      615   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 386      616   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 387      617   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 388      618   2011-01-28  Spring  Not a Holiday  Weekend or Holiday
# 389      619   2011-01-29  Spring  Not a Holiday        Working Days
#
#                                             weathersit  \
# 0      Clear, Few clouds, Partly cloudy, Partly cloudy
# ...

# %% [markdown]
# # Skewness & Correlation

# %%
skewness_rows= Final_dataset_No_Outliers.skew()
# Out:
# C:\Users\Prakhar\AppData\Local\Temp\ipykernel_20672\1826281202.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   skewness_rows= Final_dataset_No_Outliers.skew()

# %%
skewness_rows
# Out:
# instant          0.000695
# atemp            0.452817
# windspeed        0.442715
# casual           3.408122
# registered       1.168591
# cnt              0.774196
# Total Rentals    1.037281
# dtype: float64

# %%
correlation= Final_dataset_No_Outliers.corr()
# Out:
# C:\Users\Prakhar\AppData\Local\Temp\ipykernel_20672\1985207765.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation= Final_dataset_No_Outliers.corr()

# %%
correlation
# Out:
#                 instant     atemp  windspeed    casual  registered       cnt  \
# instant        1.000000  0.076305  -0.058741  0.075074    0.129179  0.027927
# atemp          0.076305  1.000000  -0.209841  0.424497    0.136547  0.190711
# windspeed     -0.058741 -0.209841   1.000000  0.133456    0.135142  0.112568
# casual         0.075074  0.424497   0.133456  1.000000    0.377911  0.493468
# registered     0.129179  0.136547   0.135142  0.377911    1.000000  0.989053
# cnt            0.027927  0.190711   0.112568  0.493468    0.989053  1.000000
# Total Rentals  0.097286  0.167992   0.213806  0.530965    0.986440       NaN
#
#                Total Rentals
# instant             0.097286
# atemp               0.167992
# windspeed           0.213806
# casual              0.530965
# registered          0.986440
# cnt                      NaN
# Total Rentals       1.000000

# %%
sns.heatmap(correlation)
# Out:
# <Axes: >
